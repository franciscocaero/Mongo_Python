# %%
from pymongo import MongoClient
import pandas as pd

# %%
client=MongoClient('localhost',27017)

# %%
database=client.Carross
collection=database.list_collection_names()
print(collection)
# Out:
# ['Ca']

# %%
collection=database['Ca']
info=collection.find_one({'Car_name':'Tesla Model Y'})
print(info)
# Out:
# {'_id': ObjectId('6582356d8a0b064ab30c7d0a'), 'Battery': 57.5, 'Car_name': 'Tesla Model Y', 'Car_name_link': 'https://ev-database.org/car/1743/Tesla-Model-Y', 'Efficiency': 164, 'Fast_charge': 580, 'Price': {'DE': {'': 47567}}, 'Range': 350, 'Top_speed': 217, 'acceleration': {'': {'0': {'100': {'': 6.9}}}}}

# %%
df=pd.DataFrame(collection.find())
df
# Out:
#                           _id  Battery                             Car_name  \
# 0    6582356d8a0b064ab30c7d05     75.0  Tesla Model Y Long Range Dual Motor
# 1    6582356d8a0b064ab30c7d06     57.5                        Tesla Model 3
# 2    6582356d8a0b064ab30c7d07     60.5                           BYD ATTO 3
# 3    6582356d8a0b064ab30c7d08     61.7               MG MG4 Electric 64 kWh
# 4    6582356d8a0b064ab30c7d09     75.0  Tesla Model 3 Long Range Dual Motor
# ..                        ...      ...                                  ...
# 355  6582356d8a0b064ab30c7e68     46.3      Citroen e-Jumpy Combi XL 50 kWh
# 356  6582356d8a0b064ab30c7e69     46.3              Fiat E-Ulysse L2 50 kWh
# 357  6582356d8a0b064ab30c7e6a     46.3         Opel Vivaro-e Combi L 50 kWh
# 358  6582356d8a0b064ab30c7e6b     68.0          Opel Zafira-e Life M 75 kWh
# 359  6582356d8a0b064ab30c7e6c     46.3              Fiat E-Ulysse L3 50 kWh
#
# ...

# %%
df.isnull().sum()
# Out:
# _id              0
# Battery          0
# Car_name         0
# Car_name_link    0
# Efficiency       0
# Fast_charge      0
# Price            0
# Range            0
# Top_speed        0
# acceleration     0
# dtype: int64

# %%
df[(df['Car_name'].str.contains("Tesla")) & (df['Efficiency']>=190)]
# Out:
#                           _id  Battery                  Car_name  \
# 103  6582356d8a0b064ab30c7d6c     95.0  Tesla Model X Dual Motor
# 107  6582356d8a0b064ab30c7d70     95.0       Tesla Model X Plaid
#
#                                          Car_name_link  Efficiency  \
# 103  https://ev-database.org/car/1407/Tesla-Model-X...         200
# 107  https://ev-database.org/car/1408/Tesla-Model-X...         209
#
#     Fast_charge                 Price  Range  Top_speed  \
# 103         660  {'DE': {'': 100970}}    475        250
# 107         630  {'DE': {'': 115970}}    455        262
#
#                         acceleration
# 103  {'': {'0': {'100': {'': 3.9}}}}
# 107  {'': {'0': {'100': {'': 2.6}}}}

# %%
df[(df['Fast_charge']==300) | (df['Range']==180)]
# Out:
#                           _id  Battery  \
# 52   6582356d8a0b064ab30c7d39     28.9
# 73   6582356d8a0b064ab30c7d4e     61.9
# 328  6582356d8a0b064ab30c7e4d     46.3
# 334  6582356d8a0b064ab30c7e53     46.3
# 346  6582356d8a0b064ab30c7e5f     60.0
# 353  6582356d8a0b064ab30c7e66     46.3
# 355  6582356d8a0b064ab30c7e68     46.3
# 357  6582356d8a0b064ab30c7e6a     46.3
# 359  6582356d8a0b064ab30c7e6c     46.3
#
#                                     Car_name  \
# 52                            Mini Cooper SE
# 73                               Honda e:Ny1
# 328          Citroen e-SpaceTourer XL 50 kWh
# 334           Toyota PROACE Shuttle L 50 kWh
# 346  Mercedes eVito Tourer Extra-Long 60 kWh
# 353              Opel Zafira-e Life L 50 kWh
# 355          Citroen e-Jumpy Combi XL 50 kWh
# 357             Opel Vivaro-e Combi L 50 kWh
# 359                  Fiat E-Ulysse L3 50 kWh
#
#                                          Car_name_link  Efficiency  \
# ...

# %%
df[((df['Battery']>45) & (df['Battery']<47)) | ((df['Battery']>60)  & (df['Battery']<63))].head(7)
# Out:
#                          _id  Battery                Car_name  \
# 2   6582356d8a0b064ab30c7d07     60.5              BYD ATTO 3
# 3   6582356d8a0b064ab30c7d08     61.7  MG MG4 Electric 64 kWh
# 23  6582356d8a0b064ab30c7d1c     60.5    BYD DOLPHIN 60.4 kWh
# 34  6582356d8a0b064ab30c7d27     62.0                Smart #1
# 47  6582356d8a0b064ab30c7d34     46.3           Peugeot e-208
# 63  6582356d8a0b064ab30c7d44     46.3            Opel Corsa-e
# 65  6582356d8a0b064ab30c7d46     46.3            Citroen e-C4
#
#                                         Car_name_link  Efficiency Fast_charge  \
# 2         https://ev-database.org/car/1782/BYD-ATTO-3         183         370
# 3   https://ev-database.org/car/1708/MG-MG4-Electr...         171         630
# 23  https://ev-database.org/car/1919/BYD-DOLPHIN-6...         178         340
# 34           https://ev-database.org/car/1667/Smart-1         185         520
# 47     https://ev-database.org/car/1583/Peugeot-e-208         162         460
# ...

# %%
df[(df['Efficiency']==df['Top_speed']) | (df['Fast_charge']==df['Range'])].tail(8)
# Out:
#                           _id  Battery                             Car_name  \
# 93   6582356d8a0b064ab30c7d62     74.0               Kia EV6 Long Range AWD
# 140  6582356d8a0b064ab30c7d91     70.0              MG Marvel R Performance
# 150  6582356d8a0b064ab30c7d9b     90.0                Mercedes EQV 300 Long
# 154  6582356d8a0b064ab30c7d9f    123.0          VinFast VF 9 Extended Range
# 216  6582356d8a0b064ab30c7ddd     64.7                    Mini Countryman E
# 221  6582356d8a0b064ab30c7de2     90.0    Mercedes eVito Tourer Long 90 kWh
# 246  6582356d8a0b064ab30c7dfb     89.0  Audi Q8 e-tron Sportback 50 quattro
# 315  6582356d8a0b064ab30c7e40     90.0          Mercedes EQV 300 Extra-Long
#
#                                          Car_name_link  Efficiency  \
# 93   https://ev-database.org/car/1482/Kia-EV6-Long-...         185
# 140  https://ev-database.org/car/1475/MG-Marvel-R-P...         200
# 150  https://ev-database.org/car/1240/Mercedes-EQV-...         290
# ...

# %%
df[(df['Car_name_link'].str.contains("1409")) | (df['Car_name_link'].str.contains("1712"))]
# Out:
#                          _id  Battery          Car_name  \
# 52  6582356d8a0b064ab30c7d39     28.9    Mini Cooper SE
# 87  6582356d8a0b064ab30c7d5c    106.5  Fisker Ocean One
#
#                                         Car_name_link  Efficiency Fast_charge  \
# 52    https://ev-database.org/car/1409/Mini-Cooper-SE         161         260
# 87  https://ev-database.org/car/1712/Fisker-Ocean-One         201         630
#
#                   Price  Range  Top_speed                     acceleration
# 52  {'DE': {'': 35700}}    180        150  {'': {'0': {'100': {'': 7.3}}}}
# 87  {'DE': {'': 69950}}    530        205  {'': {'0': {'100': {'': 3.9}}}}

# %%
df[(df['Car_name'].str.contains("90 kWh")) ]
# Out:
#                           _id  Battery  \
# 221  6582356d8a0b064ab30c7de2     90.0
# 305  6582356d8a0b064ab30c7e36     90.0
#
#                                     Car_name  \
# 221        Mercedes eVito Tourer Long 90 kWh
# 305  Mercedes eVito Tourer Extra-Long 90 kWh
#
#                                          Car_name_link  Efficiency  \
# 221  https://ev-database.org/car/1615/Mercedes-eVit...         290
# 305  https://ev-database.org/car/1616/Mercedes-eVit...         295
#
#     Fast_charge                Price  Range  Top_speed  \
# 221         310  {'DE': {'': 64248}}    310        160
# 305         310  {'DE': {'': 65140}}    305        160
#
#                        acceleration
# 221  {'': {'0': {'100': {'': 12}}}}
# 305  {'': {'0': {'100': {'': 12}}}}

# %%
df[(df['Car_name'].str.contains("Polestar")) | (df['Car_name'].str.contains("Lucid"))]
# Out:
#                           _id  Battery  \
# 66   6582356d8a0b064ab30c7d47     94.0
# 67   6582356d8a0b064ab30c7d48    118.0
# 76   6582356d8a0b064ab30c7d51     79.0
# 96   6582356d8a0b064ab30c7d65     94.0
# 121  6582356d8a0b064ab30c7d7e     79.0
# 131  6582356d8a0b064ab30c7d88    112.0
# 133  6582356d8a0b064ab30c7d8a     67.0
# 139  6582356d8a0b064ab30c7d90    107.0
# 147  6582356d8a0b064ab30c7d98    118.0
# 183  6582356d8a0b064ab30c7dbc     92.0
# 213  6582356d8a0b064ab30c7dda     92.0
# 219  6582356d8a0b064ab30c7de0    107.0
# 240  6582356d8a0b064ab30c7df5     79.0
#
#                                    Car_name  \
# 66         Polestar 4 Long Range Dual Motor
# 67                Lucid Air Dream Edition R
# 76       Polestar 2 Long Range Single Motor
# 96       Polestar 4 Long Range Single Motor
# 121        Polestar 2 Long Range Dual Motor
# 131                 Lucid Air Grand Touring
# 133  Polestar 2 Standard Range Single Motor
# 139        Polestar 3 Long Range Dual motor
# ...

# %%
df[(df['Car_name'].str.contains("AWD")) & ((df['Top_speed']!=180) & (df['Fast_charge']!=700))]
# Out:
#                           _id  Battery                        Car_name  \
# 46   6582356d8a0b064ab30c7d33     96.0            Kia EV9 99.8 kWh AWD
# 54   6582356d8a0b064ab30c7d3b     74.0  Hyundai IONIQ 6 Long Range AWD
# 85   6582356d8a0b064ab30c7d5a     64.0             Subaru Solterra AWD
# 93   6582356d8a0b064ab30c7d62     74.0          Kia EV6 Long Range AWD
# 105  6582356d8a0b064ab30c7d6e     74.0  Hyundai IONIQ 5 Long Range AWD
# 126  6582356d8a0b064ab30c7d83     96.0    Kia EV9 99.8 kWh AWD GT-Line
# 143  6582356d8a0b064ab30c7d94     64.0                 Toyota bZ4X AWD
# 198  6582356d8a0b064ab30c7dcb     93.1        XPENG G9 AWD Performance
# 213  6582356d8a0b064ab30c7dda     92.0              Lucid Air Pure AWD
# 281  6582356d8a0b064ab30c7e1e     82.7        XPENG P7 AWD Performance
#
#                                          Car_name_link  Efficiency  \
# 46   https://ev-database.org/car/1835/Kia-EV9-998-k...         226
# ...

# %%
df[df['Efficiency']==(df['Battery']*2)]
# Out:
#                           _id  Battery                      Car_name  \
# 41   6582356d8a0b064ab30c7d2e     82.5  BYD SEAL 82.5 kWh RWD Design
# 155  6582356d8a0b064ab30c7da0     90.0               NIO ET5 100 kWh
# 238  6582356d8a0b064ab30c7df3     94.0       Zeekr 001 Privilege AWD
#
#                                          Car_name_link  Efficiency  \
# 41   https://ev-database.org/car/2001/BYD-SEAL-825-...         165
# 155   https://ev-database.org/car/1787/NIO-ET5-100-kWh         180
# 238  https://ev-database.org/car/1935/Zeekr-001-Pri...         188
#
#     Fast_charge                Price  Range  Top_speed  \
# 41          550  {'DE': {'': 47578}}    500        180
# 155         520  {'DE': {'': 68500}}    500        200
# 238         700  {'DE': {'': 68970}}    500        200
#
#                         acceleration
# 41   {'': {'0': {'100': {'': 5.9}}}}
# 155    {'': {'0': {'100': {'': 4}}}}
# 238  {'': {'0': {'100': {'': 3.8}}}}

# %%
df[df['Range']==(df['Efficiency']+df['Top_speed'])]
# Out:
#                           _id  Battery                 Car_name  \
# 118  6582356d8a0b064ab30c7d7b     62.0                 Smart #3
# 179  6582356d8a0b064ab30c7db8     66.5  Mercedes EQA 350 4MATIC
# 201  6582356d8a0b064ab30c7dce     66.5  Mercedes EQA 300 4MATIC
#
#                                          Car_name_link  Efficiency  \
# 118           https://ev-database.org/car/1999/Smart-3         175
# 179  https://ev-database.org/car/1496/Mercedes-EQA-...         190
# 201  https://ev-database.org/car/1495/Mercedes-EQA-...         190
#
#     Fast_charge                Price  Range  Top_speed  \
# 118         550  {'DE': {'': 43490}}    355        180
# 179         500   {'DE': {'': 'NA'}}    350        160
# 201         500   {'DE': {'': 'NA'}}    350        160
#
#                         acceleration
# 118  {'': {'0': {'100': {'': 6.7}}}}
# 179    {'': {'0': {'100': {'': 6}}}}
# 201  {'': {'0': {'100': {'': 7.7}}}}
